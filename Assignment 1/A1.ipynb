# %% [markdown]
# # Assignment 1 (10 Marks)
#
# ### Name: Vikas Movva
# ### Student ID: movv7230
#
# Our dataset contains weekly retail prices of three grades of gasoline, diesel, auto propane and compressed natural gas in 10 Ontario markets. It is downloaded from https://data.ontario.ca/dataset/fuels-price-survey-information. Please plot the following visualizations. Your visualization should be complete.
#
# You can feel free to use the plotting packages in python. Please submit the ipynb file only.

# %%
# %pip install pandas matplotlib seaborn numpy scikit-learn plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('energy-price.csv')
# change date to datetime
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#    _id       Date  Ottawa  Toronto West/Ouest  Toronto East/Est  Windsor  \
# 0    1 1990-01-03    55.9                49.1              48.7     45.2
# 1    2 1990-01-10    55.9                47.7              46.8     49.7
# 2    3 1990-01-17    55.9                53.2              53.2     49.6
# 3    4 1990-01-24    55.9                53.2              53.5     49.0
# 4    5 1990-01-31    55.9                51.9              52.6     48.6
#
#    London  Peterborough  St. Catharine's  Sudbury  ...  Thunder Bay  \
# 0    50.1           0.0              0.0     56.4  ...         56.6
# 1    47.6           0.0              0.0     56.4  ...         56.8
# 2    53.7           0.0              0.0     55.8  ...         56.8
# 3    52.1           0.0              0.0     55.7  ...         56.8
# 4    49.1           0.0              0.0     55.6  ...         56.8
#
#    North Bay  Timmins  Kenora  Parry Sound  \
# 0       55.1     58.1     0.0          0.0
# ...

# %%
df['Fuel Type'].unique()
# Out:
# array(['Regular Unleaded Gasoline', 'Diesel', 'Compressed Natural Gas',
#        'Mid-Grade Gasoline', 'Premium Gasoline', 'Auto Propane'],
#       dtype=object)

# %% [markdown]
# ## Question 1
#
# Compare the mean prices of Regular Unleaded Gasoline among different cities ('Ottawa', 'Toronto West/Ouest', 'Toronto East/Est', 'Windsor','London', 'Peterborough', 'Sudbury', 'Sault Saint Marie', 'Thunder Bay', 'North Bay', 'Timmins', 'Kenora', 'Parry Sound',"St. Catharine's") in 2023, and plot a corresponding bar chart. Please ensure that the bars are sorted by the price amounts.

# %%
# Compare the mean prices of Regular Unleaded Gasoline among different cities ('Ottawa', 'Toronto West/Ouest', 'Toronto East/Est', 'Windsor','London', 'Peterborough', 'Sudbury', 'Sault Saint Marie', 'Thunder Bay', 'North Bay', 'Timmins', 'Kenora', 'Parry Sound',"St. Catharine's") in 2023, and plot a corresponding bar chart. Please ensure that the bars are sorted by the price amounts.
df_2023 = df[df['Date'].dt.year == 2023]
df_2023.head()
# Out:
#        _id       Date  Ottawa  Toronto West/Ouest  Toronto East/Est  Windsor  \
# 1722  1723 2023-01-03   148.3               149.4             148.7    148.3
# 1723  1724 2023-01-09   138.7               139.7             139.3    139.2
# 1724  1725 2023-01-16   149.2               150.4             150.0    149.3
# 1725  1726 2023-01-23   154.1               154.3             153.8    153.9
# 1726  1727 2023-01-30   150.5               150.7             150.3    149.6
#
#       London  Peterborough  St. Catharine's  Sudbury  ...  Thunder Bay  \
# 1722   148.8         138.6            147.1    138.6  ...        143.8
# 1723   138.8         134.2            138.8    145.9  ...        148.5
# 1724   150.4         136.7            147.4    137.8  ...        150.7
# 1725   152.6         147.2            150.3    141.0  ...        151.0
# 1726   150.1         148.7            149.4    155.5  ...        159.3
#
#       North Bay  Timmins  Kenora  Parry Sound  \
# ...

# %%
# filter for fuel type 'Regular Unleaded Gasoline', select only the columns with numerical values and drop the '_id' column
df_2023_regular = df_2023[df_2023['Fuel Type'] == 'Regular Unleaded Gasoline'].select_dtypes(include=['float64', 'int64']).drop(columns=['_id', 'Ontario Average/Moyenne provinciale', 'Southern Average/Moyenne du sud de l\'Ontario', 'Northern Average/Moyenne du nord de l\'Ontario'])
mean_values = df_2023_regular.mean()
mean_values
# Out:
# Ottawa                153.666667
# Toronto West/Ouest    154.603922
# Toronto East/Est      154.009804
# Windsor               153.239216
# London                154.005882
# Peterborough          146.501961
# St. Catharine's       151.672549
# Sudbury               151.492157
# Sault Saint Marie     155.601961
# Thunder Bay           158.288235
# North Bay             157.400000
# Timmins               163.070588
# Kenora                166.629412
# Parry Sound           156.305882
# dtype: float64

# %%
# plot the bar chart sorted by the price amounts
mean_values.sort_values().plot(kind='barh')
plt.title('Mean prices of Regular Unleaded Gasoline among different cities in 2023')
plt.xlabel('Mean price')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %% [markdown]
# ## Question 2
# Plot the corresponding dot plot for the same information presented in Question 1.

# %%
# Plot the corresponding dot plot for the same information presented in Question 1.
mean_values = mean_values.sort_values() #.plot(kind='scatter', x=mean_values.index, y=mean_values.values)
#swap x-axis for y-axis and y-axis for x-axis
fig, ax = plt.subplots()
ax.scatter(x=mean_values.values, y=mean_values.index)
plt.title('Mean prices of Regular Unleaded Gasoline among different cities in 2023')
plt.ylabel('City')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ## Question 3
#
# Plot a histogram of the Regular Unleaded Gasoline prices in Toronto West/Ouest for 2023, using 15 bins.

# %%
# Plot a histogram of the Regular Unleaded Gasoline prices in Toronto West/Ouest for 2023, using 15 bins. 
df_2023_regular['Toronto West/Ouest'].hist(bins=15)
plt.title('Frequency of Regular Unleaded Gasoline prices in Toronto West/Ouest in 2023')
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ## Question 4
#
# Plot the normalized ECDF (Empirical Cumulative Distribution Function) of the Regular Unleaded Gasoline prices in Toronto West/Ouest for 2023.

# %%
# Plot the normalized ECDF (Empirical Cumulative Distribution Function) of the Regular Unleaded Gasoline prices in Toronto West/Ouest for 2023.
# sort the prices in ascending order
sorted_prices = np.sort(df_2023_regular['Toronto West/Ouest'])
# calculate the y-axis values for the ECDF
y_values = np.arange(1, len(sorted_prices) + 1) / len(sorted_prices)
# plot the ECDF
plt.step(sorted_prices, y_values, where='post')
plt.title('ECDF of Regular Unleaded Gasoline Prices in Toronto West/Ouest for 2023')
plt.xlabel('Regular Unleaded Gasoline Price')
plt.ylabel('ECDF')
plt.show()

# %% [markdown]
# ## Question 5
#
# Plot a boxplot to display the distribution of prices across different cities ('Ottawa', 'Toronto West/Ouest', 'Toronto East/Est', 'Windsor','London', 'Peterborough', 'Sudbury', 'Sault Saint Marie', 'Thunder Bay', 'North Bay', 'Timmins', 'Kenora', 'Parry Sound',"St. Catharine's") from 2021 onwards (including 2021).

# %%
# get all rows with year >= 2021
df_2021 = df[df['Date'].dt.year >= 2021]
df_2021 = df[df['Fuel Type'] == 'Regular Unleaded Gasoline']

# only get columns 'Ottawa', 'Toronto West/Ouest', 'Toronto East/Est', 'Windsor','London', 'Peterborough', 'Sudbury', 'Sault Saint Marie', 'Thunder Bay', 'North Bay', 'Timmins', 'Kenora', 'Parry Sound',"St. Catharine's"
df_2021 = df_2021[['Ottawa', 'Toronto West/Ouest', 'Toronto East/Est', 'Windsor','London', 'Peterborough', 'Sudbury', 'Sault Saint Marie', 'Thunder Bay', 'North Bay', 'Timmins', 'Kenora', 'Parry Sound',"St. Catharine's"]]

# remove rows with 0 values
df_2021 = df_2021[(df != 0).all(axis=1)]

# Plot a boxplot to display the distribution of prices across different cities
df_2021.plot(kind='box')
plt.title('Distribution of Regular Unleaded Gasoline Prices across different cities in 2021 and beyond')
plt.xticks(rotation='vertical')
plt.ylabel('Regular Unleaded Gasoline Price')
plt.xlabel('City')
plt.show()
# Out:
# /var/folders/k8/s914kb5x6gg509bppy84_kg40000gn/T/ipykernel_86706/1810991457.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2021 = df_2021[(df != 0).all(axis=1)]
